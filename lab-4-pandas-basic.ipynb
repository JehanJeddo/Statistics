# %% [markdown]
# # Pandas
#  Basics <hr style = "border:2.5px solid #0000FF"></hr>

# %% [markdown]
# <b> Jehan Jedd Chavez </b>
# <br> Comptech Student T09

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DATAFRAME

# %%
data ={
    "Name": ['Henry','Ian','Lorenz'],
    "Age": [42,21,21],
    "Sex":['M','M','F']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Name  Age Sex
# 0   Henry   42   M
# 1     Ian   21   M
# 2  Lorenz   21   F

# %% [markdown]
# # SERIES

# %%
age_col = df['Age']

# %%
type(age_col)
# Out:
# pandas.core.series.Series

# %%
age_col
# Out:
# 0    42
# 1    21
# 2    21
# Name: Age, dtype: int64

# %%
df['Name']
# Out:
# 0     Henry
# 1       Ian
# 2    Lorenz
# Name: Name, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
# Jaguar vs Panther
resistance = np.array ([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
]).T

print (resistance)
# Out:
# [[10.6 10.1]
#  [ 9.1 11. ]
#  [ 9.3  9.1]
#  [ 9.8 20. ]
#  [10.5  9.2]
#  [10.4 10.8]
#  [ 9.5  9.9]
#  [11.   9.2]
#  [10.4  9.1]
#  [ 3.   9.1]
#  [ 9.8  nan]]

# %%
df = pd.DataFrame(resistance,columns=['Jaguar','Panther'])
df
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8      NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Jaguar']
# Out:
# 0     10.6
# 1      9.1
# 2      9.3
# 3      9.8
# 4     10.5
# 5     10.4
# 6      9.5
# 7     11.0
# 8     10.4
# 9      3.0
# 10     9.8
# Name: Jaguar, dtype: float64

# %%
# Summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
df.isna().sum()
# Out:
# Jaguar     0
# Panther    1
# dtype: int64

# %%
df.notnull()
# Out:
#     Jaguar  Panther
# 0     True     True
# 1     True     True
# 2     True     True
# 3     True     True
# 4     True     True
# 5     True     True
# 6     True     True
# 7     True     True
# 8     True     True
# 9     True     True
# 10    True    False

# %%
df.dropna()
# Out:
#    Jaguar  Panther
# 0    10.6     10.1
# 1     9.1     11.0
# 2     9.3      9.1
# 3     9.8     20.0
# 4    10.5      9.2
# 5    10.4     10.8
# 6     9.5      9.9
# 7    11.0      9.2
# 8    10.4      9.1
# 9     3.0      9.1

# %%
df.fillna(100)
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8    100.0

# %%
df['Panther'].fillna(df['Panther'].mean())
# Out:
# 0     10.10
# 1     11.00
# 2      9.10
# 3     20.00
# 4      9.20
# 5     10.80
# 6      9.90
# 7      9.20
# 8      9.10
# 9      9.10
# 10    10.75
# Name: Panther, dtype: float64

# %%
df
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8      NaN

# %%
# Summary of statistics
df.describe()
# Out:
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    9.400000  10.750000
# std     2.204541   3.329081
# min     3.000000   9.100000
# 25%     9.400000   9.125000
# 50%     9.800000   9.550000
# 75%    10.450000  10.625000
# max    11.000000  20.000000

# %%
# median
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()
print(f'Jaguar Median= {jag_median:.2f} ohms')
print(f'Panther Median= {pan_median:.2f} ohms')
# Out:
# Jaguar Median= 9.80 ohms
# Panther Median= 9.55 ohms

# %%
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

# %%
jag_mode
# Out:
# 0     9.8
# 1    10.4
# Name: Jaguar, dtype: float64

# %%
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print('Jaguar Mode')

for i in jag_mode:
    print(i)
# Out:
# Jaguar Mode
# 9.8
# 10.4

# %%
print('Panther Mode')

for i in pan_mode:
    print(i)
# Out:
# Panther Mode
# 9.1

# %%
# Jaguar IQR

Q1 = df['Jaguar'].quantile(.25)
Q3 = df['Jaguar'].quantile(.75)

print(f'Jaguar IQR {Q3 - Q1:.2f} ohms')
# Out:
# Jaguar IQR 1.05 ohms

# %%
# Panther IQR

Q1 = df['Panther'].quantile(.25)
Q3 = df['Panther'].quantile(.75)

print(f'Panther IQR {Q3 - Q1:.2f} ohms')
# Out:
# Panther IQR 1.50 ohms

# %% [markdown]
# # Bar Chart

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure()
bars = plt.bar(['Jaguar','Panther'],[jag_mean,pan_mean],
        color= "#0000FF")
plt.title('Average Resistance by Machine')
plt.ylabel('Resistance (ohms)')

#Label
plt.bar_label(bars, padding=3)
plt.margins(y=.5)
plt.show()
