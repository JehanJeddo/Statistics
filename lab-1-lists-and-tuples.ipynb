# %% [markdown]
# # List and Tuples <hr style = "border:2.5px solid #0000FF"></hr>

# %% [markdown]
# <b> Jehan Jedd Chavez </b>
# <br> Comptech Student T09

# %% [markdown]
# # Creating a List

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers[2]
# Out:
# 3

# %%
numbers[-2]
# Out:
# 4

# %%
type(numbers)
# Out:
# list

# %%
mixed_list = [10, 'hello', 2.5, True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# # Modifying Elements

# %%
fruits=['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits[0]='orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
fruits[-2]='blueberry'
fruits
# Out:
# ['orange', 'blueberry', 'grape']

# %% [markdown]
# # Adding Elements

# %%
fruits=['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(2,'blueberry')
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits=['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
'orange' in fruits
# Out:
# False

# %%
fruits.remove('banana')

# %%
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['grape']

# %% [markdown]
# # sort() and sorted()

# %%
numbers = [3,1,2,5,4]
numbers
# Out:
# [3, 1, 2, 5, 4]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers.sort(reverse=False)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Slicing

# %%
numbers = [3,5,1,3,4,3,4,3,2,4,2]
numbers
# Out:
# [3, 5, 1, 3, 4, 3, 4, 3, 2, 4, 2]

# %%
len(numbers)
# Out:
# 11

# %%
numbers[1:5]
# Out:
# [5, 1, 3, 4]

# %%
numbers[0:8:2]
# Out:
# [3, 1, 4, 4]

# %% [markdown]
# # Tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)
